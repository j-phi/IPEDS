# %% [markdown]
# <a href="https://colab.research.google.com/github/j-phi/IPEDS/blob/master/IPEDS_Category_Filler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![IPEDS LOGO](https://drive.google.com/uc?export=view&id=1OgR-yDdjZToLc56BxF-oaA9zRK7iDKva)](https://nces.ed.gov/ipeds/datacenter/Data.aspx)
#
# # IPEDS Compare Institutions Datacenter Category Decoder
#
# IPEDS has great ["Compare Institutions"](https://nces.ed.gov/ipeds/datacenter/Data.aspx) feature that allows for large-scale downloading of data on multiple institutions. The challenge is that all of the columns are automatically encoded as numeric values by default.
#
# As an example, a University might be classifiable into two categories: 'Two Year' and 'Four Year'. In the dataset, instead of listing those values, the value will be encoded as '1' and '2'. You have the option of downloading a separate spreadsheet of value labels that explains the encoding for every column, but with most columns being encoded and many columns having a high number of possible options, it's too cumbersome to quickly analyze without an analytics platform like SAS or SPSS.
#
# As such, this script will automate the process of decoding the data. It accepts the data file and the value labels file, and then automatically re-converts the numerical representations into their original form.
#
# Sample files are available here:
# * [Data](https://drive.google.com/file/d/15dWlNWpp-Q7hEEUus6oHueDAsRZVqw3B/view?usp=sharing)
# * [Value Labels](https://drive.google.com/file/d/1EuB6lfYhY6P_7U3eXu5i2BDziJMm4skB/view?usp=sharing)

# %% [markdown]
# ## Imports and Settings

# %%
from google.colab import files
import sys
import pandas as pd
import numpy as np
from datetime import datetime as dt
from ipywidgets import widgets
from IPython.display import display
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %% [markdown]
# ## Upload Files
#
# To begin, upload **both your data and value label files** from your IPEDS download. To get the value label files, note that you have to select `"Yes"` to `"Do you want to include value labels?"` on the final data download step.
#
# If this throws an error message, just re-run the cell until you have a `Browse...` button without the error message.

# %%
uploaded = files.upload()

for fn in uploaded.keys():
  print(f'[✓] Uploaded file "{fn}" with length {round(len(uploaded[fn])/1000000,2):,}MB')
# Out:
#      <input type="file" id="files-e28b0498-019c-4027-ace1-47faa6b20bdf" name="files[]" multiple disabled />
#      <output id="result-e28b0498-019c-4027-ace1-47faa6b20bdf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Data_9-2-2019---119.csv to Data_9-2-2019---119 (8).csv
# Saving ValueLabels_9-2-2019---119.csv to ValueLabels_9-2-2019---119 (8).csv
# [✓] Uploaded file "Data_9-2-2019---119.csv" with length 1.29MB
# [✓] Uploaded file "ValueLabels_9-2-2019---119.csv" with length 0.1MB

# %% [markdown]
# Let's extract the relevant file names.

# %%
data_loc = ''
labels_loc = ''

for fn in uploaded.keys():
  if 'data' in fn.lower():
    data_loc = fn
  elif 'valuelabels' in fn.lower():
    labels_loc = fn

datavaluestr = f'[✓] Data and Value Label Files identified. \
Data file: {data_loc} | Value label file: {labels_loc}'

if data_loc != '' and labels_loc != '':
  print(datavaluestr)
else:
  print(f'It does not look like you uploaded your data and valuelabel files. Here is what we have: \n {datavaluestr}')
# Out:
# [✓] Data and Value Label Files identified. Data file: Data_9-2-2019---119.csv | Value label file: ValueLabels_9-2-2019---119.csv

# %% [markdown]
# ## Decode the Files

# %% [markdown]
# Next, we'll ingest our data from .csv files into pandas dataframes. We'll call them `df` for the dataframe that houses our data and `labels` for the dataframe that houses our labels.

# %%
df = pd.read_csv(data_loc)
labels = pd.read_csv(labels_loc)

# %%
df.head()
# Out:
#    UnitID                         Institution Name  FIPS state code (HD2017)  \
# 0  177834  A T Still University of Health Sciences                        29
# 1  180203                   Aaniiih Nakoda College                        30
# 2  459523                       ABC Beauty Academy                        48
# 3  485500                          ABCO Technology                         6
# 4  461892                         Abcott Institute                        26
#
#         Institution (entity) name (HD2017) Institution name alias (HD2017)  \
# 0  A T Still University of Health Sciences                             NaN
# 1                   Aaniiih Nakoda College                             NaN
# 2                       ABC Beauty Academy                             NaN
# 3                          ABCO Technology                             NaN
# 4                         Abcott Institute                             NaN
#
#   State abbreviation (HD2017) City location of institution (HD2017)  \
# 0                          MO                            Kirksville
# 1                          MT                                Harlem
# 2                          TX                            Richardson
# 3                          CA                             Inglewood
# 4                          MI                            Southfield
#
#   ZIP code (HD2017)  Fips County code (HD2017)  \
# 0             63501                      29001
# 1             59526                      30005
# 2             75081                      48113
# 3        90304-1551                       6037
# 4        48075-5227                      26125
#
#    Longitude location of institution (HD2017)  \
# 0                                  -92.589183
# 1                                 -108.757816
# 2                                  -96.685333
# 3                                 -118.369774
# 4                                  -83.210617
#
#    Latitude location of institution (HD2017) Status of institution (HD2017)  \
# 0                                  40.193648                              A
# 1                                  48.484196                              A
# 2                                  32.931698                              A
# 3                                  33.932121                              A
# 4                                  42.446331                              A
#
#    Sector of institution (HD2017)  Level of institution (HD2017)  \
# 0                               2                              1
# 1                               4                              2
# 2                               9                              3
# 3                               9                              3
# 4                               9                              3
#
#    Control of institution (HD2017)  \
# 0                                2
# 1                                1
# 2                                3
# 3                                3
# 4                                3
#
#    Historically Black College or University (HD2017)  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#    Degree of urbanization (Urban-centric locale) (HD2017)  \
# 0                                                 33
# 1                                                 43
# 2                                                 12
# 3                                                 21
# 4                                                 13
#
#    Carnegie Classification 2015: Undergraduate Instructional Program (HD2017)  \
# 0                                                  0
# 1                                                 15
# 2                                                 -2
# 3                                                 -2
# 4                                                 -2
#
#    Carnegie Classification 2015: Graduate Instructional Program (HD2017)  \
# 0                                                 18
# 1                                                  0
# 2                                                 -2
# 3                                                 -2
# 4                                                 -2
#
#    Carnegie Classification 2015: Enrollment Profile (HD2017)  \
# 0                                                  7
# 1                                                  1
# 2                                                 -2
# 3                                                 -2
# 4                                                 -2
#
#    Carnegie Classification 2015: Undergraduate Profile (HD2017)  \
# 0                                                  0
# 1                                                  1
# 2                                                 -2
# 3                                                 -2
# 4                                                 -2
#
#    Carnegie Classification 2015: Size and Setting (HD2017)  \
# 0                                                 18
# 1                                                  1
# 2                                                 -2
# 3                                                 -2
# 4                                                 -2
#
#    Land Grant Institution (HD2017)  Institution size category (HD2017)  \
# 0                                2                                   2
# 1                                1                                   1
# 2                                2                                   1
# 3                                2                                   1
# 4                                2                                   1
#
#    Institutional category (HD2017)  \
# 0                                1
# 1                                4
# 2                                6
# 3                                6
# 4                                6
#
#    Bureau of Economic Analysis (BEA) regions (HD2017)  \
# 0                                                  4
# 1                                                  7
# 2                                                  6
# 3                                                  8
# 4                                                  3
#
#    Does institution have a tenure system (FLAGS2017)  \
# 0                                                  1
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#    Total price for in-state students living on campus 2017-18 (DRVIC2017)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Total price for out-of-state students living on campus 2017-18 (DRVIC2017)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Percent of full-time first-time undergraduates awarded Pell grants (SFA1617)  \
# 0                                                NaN
# 1                                               85.0
# 2                                                0.0
# 3                                               50.0
# 4                                              100.0
#
#    Average amount of Pell grant aid awarded to full-time first-time undergraduates (SFA1617)  \
# 0                                                NaN
# 1                                             4091.0
# 2                                                NaN
# 3                                             4479.0
# 4                                             2906.0
#
#    Total  enrollment (DRVEF2017)  Unnamed: 32
# 0                         3723.0          NaN
# 1                          122.0          NaN
# 2                            NaN          NaN
# 3                           50.0          NaN
# 4                          151.0          NaN

# %% [markdown]
# ### Float Conversion
#
# Because most numeric columns have blank values on occasion, Pandas saves them as floats (numbers with decimals) by default. Because it doesn't necessarily make sense for them to have decimals (you can't have a fraction of a student, for instance), let's convert all of the floats to `Int64` columns: these are special integer columns that can accomodate blank values. We'll first define a few columns that should stay as floats in the list `floatlist`; feel free to add other columns as needed.
#
#
# ### Dictionary Creation
#
# Next, let's use the dataframe of value labels to create a dictionary, label_dict that will contain each encoded column's names as keys and subdictionaries in each of those as values containing the encoded value and decoded value.
#
# It will look like this:
#
#     {'Bureau of Economic Analysis (BEA) regions (HD2017)':
#       {'0': 'US Service schools',
#       '1': 'New England CT ME MA NH RI VT',
#       '2': 'Mid East DE DC MD NJ NY PA',
#       '3': 'Great Lakes IL IN MI OH WI',
#       '4': 'Plains IA KS MN MO NE ND SD',
#       '5': 'Southeast AL AR FL GA KY LA MS NC SC TN VA WV',
#       '6': 'Southwest AZ NM OK TX',
#       '7': 'Rocky Mountains CO ID MT UT WY',
#       '8': 'Far West AK CA HI NV OR WA'},
#     'Carnegie Classification 2015: Enrollment Profile (HD2017)':
#       {'-2': 'Not applicable, not in Carnegie universe (not accredited or nondegree-granting)',
#       '1': 'Exclusively undergraduate two-year',
#       '2': 'Exclusively undergraduate four-year',
#       '3': 'Very high undergraduate',
#       '4': 'High undergraduate',
#       '5': 'Majority undergraduate',
#       '6': 'Majority graduate',
#       '7': 'Exclusively graduate'
#       },...
#     }
#
# We'll use the label_dict dictionary to convert all encoded values back to their original values. We'll then set the dataframe index to be the institution's name.
#
# ### DROP EXTRANEOUS COLUMNS
#
# Finally, we'll drop any empty columns that may have been accidentally created.

# %%
# ------------------------------------------------------------------------------
# FLOAT CONVERSION
# ------------------------------------------------------------------------------

float_col = df.select_dtypes(include = ['float64']) # This will select float columns only

floatlist = ['Latitude location of institution (HD2017)','Longitude location of institution (HD2017)']

for col in float_col.columns.values:
    if col not in floatlist:
        df[col] = df[col].astype('Int64')
# You could confirm it worked by uncommenting this code:
# print(df[float_col.columns.values].info())

# ------------------------------------------------------------------------------
# DICTIONARY CREATION AND APPLICATION
# ------------------------------------------------------------------------------

uniquelabels = labels.VariableName.unique().tolist()

label_dict = {}
  
for label in uniquelabels:
    labeldf = labels.loc[labels['VariableName']==label,['Value','ValueLabel']]
    labeldf.rename(columns={'ValueLabel':label}, inplace=True)
    labeldf.set_index('Value',inplace=True)
    df[label] = df[label].apply(lambda x: labeldf.loc[str(x)] if str(x) != '' else '')
    # Dictionary lookup alternative:
    #dfd=labeldf.to_dict(orient='dict')
    #label_dict={**label_dict, **dfd}
    #df[label]=df[label].apply(lambda x: label_dict[label][str(x)] \
    #                          if str(x) != '' else '')

df.set_index('Institution Name', inplace=True)

# ------------------------------------------------------------------------------
# DROP EXTRANEOUS COLUMNS
# ------------------------------------------------------------------------------

# The first list comprehesion identifies both columns that have 'unnamed' in the
# title and that have a total count of NaN values equal to the number of rows 
unnamed_cols = [col for col in df.columns if 'unnamed' in col.lower() and df[col].isna().sum() == df[col].shape[0]]
if len(unnamed_cols) > 0:
  df.drop(columns=unnamed_cols, inplace=True)

# %% [markdown]
# Let's have a look at the first few rows of the dataframe to make sure things are looking accurate:

# %%
df.head()
# Out:
#                                          UnitID FIPS state code (HD2017)  \
# Institution Name
# A T Still University of Health Sciences  177834                 Missouri
# Aaniiih Nakoda College                   180203                  Montana
# ABC Beauty Academy                       459523                    Texas
# ABCO Technology                          485500               California
# Abcott Institute                         461892                 Michigan
#
#                                               Institution (entity) name (HD2017)  \
# Institution Name
# A T Still University of Health Sciences  A T Still University of Health Sciences
# Aaniiih Nakoda College                                    Aaniiih Nakoda College
# ABC Beauty Academy                                            ABC Beauty Academy
# ABCO Technology                                                  ABCO Technology
# Abcott Institute                                                Abcott Institute
#
#                                         Institution name alias (HD2017)  \
# Institution Name
# A T Still University of Health Sciences                             NaN
# Aaniiih Nakoda College                                              NaN
# ABC Beauty Academy                                                  NaN
# ABCO Technology                                                     NaN
# Abcott Institute                                                    NaN
#
#                                         State abbreviation (HD2017)  \
# Institution Name
# A T Still University of Health Sciences                    Missouri
# Aaniiih Nakoda College                                      Montana
# ABC Beauty Academy                                            Texas
# ABCO Technology                                          California
# Abcott Institute                                           Michigan
#
#                                         City location of institution (HD2017)  \
# Institution Name
# A T Still University of Health Sciences                            Kirksville
# Aaniiih Nakoda College                                                 Harlem
# ABC Beauty Academy                                                 Richardson
# ABCO Technology                                                     Inglewood
# Abcott Institute                                                   Southfield
#
#                                         ZIP code (HD2017)  \
# Institution Name
# A T Still University of Health Sciences             63501
# Aaniiih Nakoda College                              59526
# ABC Beauty Academy                                  75081
# ABCO Technology                                90304-1551
# Abcott Institute                               48075-5227
#
#                                         Fips County code (HD2017)  \
# Institution Name
# A T Still University of Health Sciences          Adair County, MO
# Aaniiih Nakoda College                          Blaine County, MT
# ABC Beauty Academy                              Dallas County, TX
# ABCO Technology                            Los Angeles County, CA
# Abcott Institute                               Oakland County, MI
#
#                                          Longitude location of institution (HD2017)  \
# Institution Name
# A T Still University of Health Sciences                                  -92.589183
# Aaniiih Nakoda College                                                  -108.757816
# ABC Beauty Academy                                                       -96.685333
# ABCO Technology                                                         -118.369774
# Abcott Institute                                                         -83.210617
#
#                                          Latitude location of institution (HD2017)  \
# Institution Name
# A T Still University of Health Sciences                                  40.193648
# Aaniiih Nakoda College                                                   48.484196
# ABC Beauty Academy                                                       32.931698
# ABCO Technology                                                          33.932121
# Abcott Institute                                                         42.446331
#
#                                         Status of institution (HD2017)  \
# Institution Name
# A T Still University of Health Sciences   Active - institution active
# Aaniiih Nakoda College                    Active - institution active
# ABC Beauty Academy                        Active - institution active
# ABCO Technology                           Active - institution active
# Abcott Institute                          Active - institution active
#
#                                                   Sector of institution (HD2017)  \
# Institution Name
# A T Still University of Health Sciences  Private not-for-profit, 4-year or above
# Aaniiih Nakoda College                                            Public, 2-year
# ABC Beauty Academy                          Private for-profit, less-than 2-year
# ABCO Technology                             Private for-profit, less-than 2-year
# Abcott Institute                            Private for-profit, less-than 2-year
#
#                                                Level of institution (HD2017)  \
# Institution Name
# A T Still University of Health Sciences                   Four or more years
# Aaniiih Nakoda College                      At least 2 but less than 4 years
# ABC Beauty Academy                       Less than 2 years (below associate)
# ABCO Technology                          Less than 2 years (below associate)
# Abcott Institute                         Less than 2 years (below associate)
#
#                                         Control of institution (HD2017)  \
# Institution Name
# A T Still University of Health Sciences          Private not-for-profit
# Aaniiih Nakoda College                                           Public
# ABC Beauty Academy                                   Private for-profit
# ABCO Technology                                      Private for-profit
# Abcott Institute                                     Private for-profit
#
#                                         Historically Black College or University (HD2017)  \
# Institution Name
# A T Still University of Health Sciences                                                No
# Aaniiih Nakoda College                                                                 No
# ABC Beauty Academy                                                                     No
# ABCO Technology                                                                        No
# Abcott Institute                                                                       No
#
#                                         Degree of urbanization (Urban-centric locale) (HD2017)  \
# Institution Name
# A T Still University of Health Sciences                                       Town: Remote
# Aaniiih Nakoda College                                                       Rural: Remote
# ABC Beauty Academy                                                           City: Midsize
# ABCO Technology                                                              Suburb: Large
# Abcott Institute                                                               City: Small
#
#                                         Carnegie Classification 2015: Undergraduate Instructional Program (HD2017)  \
# Institution Name
# A T Still University of Health Sciences     Not Classified (Exclusively Graduate Programs)
# Aaniiih Nakoda College                   Professions plus arts & sciences, no graduate ...
# ABC Beauty Academy                       Not applicable, not in Carnegie universe (not ...
# ABCO Technology                          Not applicable, not in Carnegie universe (not ...
# Abcott Institute                         Not applicable, not in Carnegie universe (not ...
#
#                                         Carnegie Classification 2015: Graduate Instructional Program (HD2017)  \
# Institution Name
# A T Still University of Health Sciences           Research Doctoral: Professional-dominant
# Aaniiih Nakoda College                          Not classified (Exclusively Undergraduate)
# ABC Beauty Academy                       Not applicable, not in Carnegie universe (not ...
# ABCO Technology                          Not applicable, not in Carnegie universe (not ...
# Abcott Institute                         Not applicable, not in Carnegie universe (not ...
#
#                                         Carnegie Classification 2015: Enrollment Profile (HD2017)  \
# Institution Name
# A T Still University of Health Sciences                               Exclusively graduate
# Aaniiih Nakoda College                                  Exclusively undergraduate two-year
# ABC Beauty Academy                       Not applicable, not in Carnegie universe (not ...
# ABCO Technology                          Not applicable, not in Carnegie universe (not ...
# Abcott Institute                         Not applicable, not in Carnegie universe (not ...
#
#                                         Carnegie Classification 2015: Undergraduate Profile (HD2017)  \
# Institution Name
# A T Still University of Health Sciences              Not classified (Exclusively Graduate)
# Aaniiih Nakoda College                                          Two-year, higher part-time
# ABC Beauty Academy                       Not applicable, not in Carnegie universe (not ...
# ABCO Technology                          Not applicable, not in Carnegie universe (not ...
# Abcott Institute                         Not applicable, not in Carnegie universe (not ...
#
#                                         Carnegie Classification 2015: Size and Setting (HD2017)  \
# Institution Name
# A T Still University of Health Sciences                  Exclusively graduate/professional
# Aaniiih Nakoda College                                                Two-year, very small
# ABC Beauty Academy                       Not applicable, not in Carnegie universe (not ...
# ABCO Technology                          Not applicable, not in Carnegie universe (not ...
# Abcott Institute                         Not applicable, not in Carnegie universe (not ...
#
#                                         Land Grant Institution (HD2017)  \
# Institution Name
# A T Still University of Health Sciences    Not a Land Grant Institution
# Aaniiih Nakoda College                           Land Grant Institution
# ABC Beauty Academy                         Not a Land Grant Institution
# ABCO Technology                            Not a Land Grant Institution
# Abcott Institute                           Not a Land Grant Institution
#
#                                         Institution size category (HD2017)  \
# Institution Name
# A T Still University of Health Sciences                      1,000 - 4,999
# Aaniiih Nakoda College                                         Under 1,000
# ABC Beauty Academy                                             Under 1,000
# ABCO Technology                                                Under 1,000
# Abcott Institute                                               Under 1,000
#
#                                                            Institutional category (HD2017)  \
# Institution Name
# A T Still University of Health Sciences  Degree-granting, graduate with no undergraduat...
# Aaniiih Nakoda College                   Degree-granting, associate's and certificates ...
# ABC Beauty Academy                                   Nondegree-granting, sub-baccalaureate
# ABCO Technology                                      Nondegree-granting, sub-baccalaureate
# Abcott Institute                                     Nondegree-granting, sub-baccalaureate
#
#                                         Bureau of Economic Analysis (BEA) regions (HD2017)  \
# Institution Name
# A T Still University of Health Sciences                        Plains IA KS MN MO NE ND SD
# Aaniiih Nakoda College                                      Rocky Mountains CO ID MT UT WY
# ABC Beauty Academy                                                   Southwest AZ NM OK TX
# ABCO Technology                                                 Far West AK CA HI NV OR WA
# Abcott Institute                                                Great Lakes IL IN MI OH WI
#
#                                         Does institution have a tenure system (FLAGS2017)  \
# Institution Name
# A T Still University of Health Sciences                                 Has tenure system
# Aaniiih Nakoda College                                                   No tenure system
# ABC Beauty Academy                                                       No tenure system
# ABCO Technology                                                          No tenure system
# Abcott Institute                                                         No tenure system
#
#                                          Total price for in-state students living on campus 2017-18 (DRVIC2017)  \
# Institution Name
# A T Still University of Health Sciences                                                NaN
# Aaniiih Nakoda College                                                                 NaN
# ABC Beauty Academy                                                                     NaN
# ABCO Technology                                                                        NaN
# Abcott Institute                                                                       NaN
#
#                                          Total price for out-of-state students living on campus 2017-18 (DRVIC2017)  \
# Institution Name
# A T Still University of Health Sciences                                                NaN
# Aaniiih Nakoda College                                                                 NaN
# ABC Beauty Academy                                                                     NaN
# ABCO Technology                                                                        NaN
# Abcott Institute                                                                       NaN
#
#                                          Percent of full-time first-time undergraduates awarded Pell grants (SFA1617)  \
# Institution Name
# A T Still University of Health Sciences                                                NaN
# Aaniiih Nakoda College                                                                  85
# ABC Beauty Academy                                                                       0
# ABCO Technology                                                                         50
# Abcott Institute                                                                       100
#
#                                          Average amount of Pell grant aid awarded to full-time first-time undergraduates (SFA1617)  \
# Institution Name
# A T Still University of Health Sciences                                                NaN
# Aaniiih Nakoda College                                                                4091
# ABC Beauty Academy                                                                     NaN
# ABCO Technology                                                                       4479
# Abcott Institute                                                                      2906
#
#                                          Total  enrollment (DRVEF2017)
# Institution Name
# A T Still University of Health Sciences                           3723
# Aaniiih Nakoda College                                             122
# ABC Beauty Academy                                                 NaN
# ABCO Technology                                                     50
# Abcott Institute                                                   151

# %% [markdown]
# ## Export the Decoded Data
#
# If this throws an error message, just re-run the cell until you are prompted to download the file.

# %%
today = dt.today().strftime('%Y-%m-%d')
filename = f'{today}-ipeds.xls'
df.to_excel(filename)
files.download(filename)
